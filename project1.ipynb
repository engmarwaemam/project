# %% [markdown]
# **Final Machine Learning project**
#
# **The dataset contains transactions made by credit cards in September 2013 by European cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.173% of all transactions

# %% [markdown]
# ### Install intial packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import scatter_matrix
import seaborn as sns

# %% [markdown]
# ### Read data file

# %%
data = pd.read_csv("creditcard.csv")
data.dataframeName='creditcard.csv'

# %% [markdown]
# ## Take a Quick Look at the Data Structure

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#There is no null values or missing values and all columns has float data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# delete duplicate rows
data = data.drop_duplicates()
# Unique values which point to data is imbalanced that almost of transactions are non fraud . 
data.apply(lambda x: len(x.unique()))
data['Class'].value_counts()
sns.countplot(x ='Class',data=data)
print('Imbalanced Class')
plt.title('Class Distribution', fontsize=14)
# Out:
# Imbalanced Class
# Text(0.5, 1.0, 'Class Distribution')

# %%
# understanding the values of columns (min-max-mean) to know if i need to scale data or not.
data.describe().transpose()
# Out:
#            count          mean           std         min           25%  \
# Time    283726.0  94811.077600  47481.047891    0.000000  54204.750000
# V1      283726.0      0.005917      1.948026  -56.407510     -0.915951
# V2      283726.0     -0.004135      1.646703  -72.715728     -0.600321
# V3      283726.0      0.001613      1.508682  -48.325589     -0.889682
# V4      283726.0     -0.002966      1.414184   -5.683171     -0.850134
# V5      283726.0      0.001828      1.377008 -113.743307     -0.689830
# V6      283726.0     -0.001139      1.331931  -26.160506     -0.769031
# V7      283726.0      0.001801      1.227664  -43.557242     -0.552509
# V8      283726.0     -0.000854      1.179054  -73.216718     -0.208828
# V9      283726.0     -0.001596      1.095492  -13.434066     -0.644221
# V10     283726.0     -0.001441      1.076407  -24.588262     -0.535578
# V11     283726.0      0.000202      1.018720   -4.797473     -0.761649
# ...

# %% [markdown]
# ## Take a Look at the Data Trend

# %%
#function for Correlation matrix
def plotCorrelationMatrix(data, graphwidth):
    data=data[[col for col in data if data[col].nunique()>1]]
    corr=data.corr()
    plt.figure(num=None, figsize=(graphwidth, graphwidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat=plt.matshow(corr, fignum=1)
    plt.xticks(range(len(corr.columns)),corr.columns, rotation=35)
    plt.yticks(range(len(corr.columns)),corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title('correlation matrix',fontsize=15)
    plt.show

# %%
plotCorrelationMatrix(data,15)

# %%
# to understand the effect of features according class column.
corr_matrix = data.corr()
corr_matrix["Class"].sort_values(ascending=False)
# Out:
# Class     1.000000
# V11       0.149067
# V4        0.129326
# V2        0.084624
# V19       0.033631
# V8        0.033068
# V21       0.026357
# V27       0.021892
# V20       0.021486
# V28       0.009682
# Amount    0.005777
# V22       0.004887
# V26       0.004265
# V25       0.003202
# V15      -0.003300
# V13      -0.003897
# V23      -0.006333
# V24      -0.007210
# Time     -0.012359
# V6       -0.043915
# V5       -0.087812
# V9       -0.094021
# V1       -0.094486
# V18      -0.105340
# V7       -0.172347
# V3       -0.182322
# V16      -0.187186
# V10      -0.206971
# V12      -0.250711
# V14      -0.293375
# V17      -0.313498
# Name: Class, dtype: float64

# %%
# to understand  trend of data between Features which has higher correlation
attributes = ['Class','V2','V4','V8','V11','V19','V20','V21','V27','V28','Amount']
scatter_matrix(data[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot: xlabel='Class', ylabel='Class'>,
#         <AxesSubplot: xlabel='V2', ylabel='Class'>,
#         <AxesSubplot: xlabel='V4', ylabel='Class'>,
#         <AxesSubplot: xlabel='V8', ylabel='Class'>,
#         <AxesSubplot: xlabel='V11', ylabel='Class'>,
#         <AxesSubplot: xlabel='V19', ylabel='Class'>,
#         <AxesSubplot: xlabel='V20', ylabel='Class'>,
#         <AxesSubplot: xlabel='V21', ylabel='Class'>,
#         <AxesSubplot: xlabel='V27', ylabel='Class'>,
#         <AxesSubplot: xlabel='V28', ylabel='Class'>,
#         <AxesSubplot: xlabel='Amount', ylabel='Class'>],
#        [<AxesSubplot: xlabel='Class', ylabel='V2'>,
#         <AxesSubplot: xlabel='V2', ylabel='V2'>,
#         <AxesSubplot: xlabel='V4', ylabel='V2'>,
#         <AxesSubplot: xlabel='V8', ylabel='V2'>,
#         <AxesSubplot: xlabel='V11', ylabel='V2'>,
#         <AxesSubplot: xlabel='V19', ylabel='V2'>,
#         <AxesSubplot: xlabel='V20', ylabel='V2'>,
# ...

# %%
# to show data distribution of features for example there is right skew columns as V10, V22, V24 and left skew columns as v17, V15, V24.
data.hist(bins=10, figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## preprocessing and sampling data

# %%
# scale Time and Amount to prone outliers
from sklearn.preprocessing import RobustScaler
robscl=RobustScaler()
data['scaled_amount']=robscl.fit_transform(data['Amount'].values.reshape(-1,1))
data['scaled_time']=robscl.fit_transform(data['Time'].values.reshape(-1,1))
data.drop(['Time', 'Amount'], axis=1, inplace=True)
data.describe().transpose()
# Out:
#                   count      mean       std         min       25%       50%  \
# V1             283726.0  0.005917  1.948026  -56.407510 -0.915951  0.020384
# V2             283726.0 -0.004135  1.646703  -72.715728 -0.600321  0.063949
# V3             283726.0  0.001613  1.508682  -48.325589 -0.889682  0.179963
# V4             283726.0 -0.002966  1.414184   -5.683171 -0.850134 -0.022248
# V5             283726.0  0.001828  1.377008 -113.743307 -0.689830 -0.053468
# V6             283726.0 -0.001139  1.331931  -26.160506 -0.769031 -0.275168
# V7             283726.0  0.001801  1.227664  -43.557242 -0.552509  0.040859
# V8             283726.0 -0.000854  1.179054  -73.216718 -0.208828  0.021898
# V9             283726.0 -0.001596  1.095492  -13.434066 -0.644221 -0.052596
# V10            283726.0 -0.001441  1.076407  -24.588262 -0.535578 -0.093237
# V11            283726.0  0.000202  1.018720   -4.797473 -0.761649 -0.032306
# ...

# %% [markdown]
# ## OVERSAMPLING and UNDERSAMPLING DATA

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
x=data.drop('Class', axis=1)
y=data['Class']
ros = RandomOverSampler(random_state=42)
smo = SMOTE(random_state=42)
uos = RandomUnderSampler(random_state=42)
tom = TomekLinks()
x_res, y_res= ros.fit_resample(x,y)
x_smo, y_smo= smo.fit_resample(x,y)
x_uos, y_uos= uos.fit_resample(x,y)
x_tom, y_tom= tom.fit_resample(x,y)

# %% [markdown]
# ## SPLITTIN DATA

# %%
from sklearn.model_selection import train_test_split
# OVERSAMPLING
data_res=x_res
data_res['Class']=y_res
plotCorrelationMatrix(data_res,15)
x_train_res, x_test_res, y_train_res, y_test_res= train_test_split(x_res, y_res, test_size=0.2, random_state=0)
x_train_smo, x_test_smo, y_train_smo, y_test_smo= train_test_split(x_smo, y_smo, test_size=0.2, random_state=0)

# %%
# correlation matrix after oversampling explain the relation between features better than original dataset

# %%
# UNDERSAMPLING
data_uos=x_uos
data_uos['Class']=y_uos
plotCorrelationMatrix(data_res,15)
x_train_uos, x_test_uos, y_train_uos, y_test_uos= train_test_split(x_uos, y_uos, test_size=0.2, random_state=0)
x_train_tom, x_test_tom, y_train_tom, y_test_tom= train_test_split(x_tom, y_tom, test_size=0.2, random_state=0)

# %%
# correlation matrix after undersampling explain the relation between features better than original dataset and the same oversampling

# %% [markdown]
# ## Modeling Data using oversampling data and XGBoost

# %%
# using oversampling data
from xgboost import XGBClassifier
XGB_model=XGBClassifier()
XGB_model.fit(x_train_res,y_train_res)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
# to test xgb modeling
y_pred_xgb=XGB_model.predict(x_test_res)
# to evaluate xgb modeling
from sklearn.metrics import confusion_matrix, classification_report
class_report=classification_report(y_test_res,y_pred_xgb)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56461
#            1       1.00      1.00      1.00     56841
#
#     accuracy                           1.00    113302
#    macro avg       1.00      1.00      1.00    113302
# weighted avg       1.00      1.00      1.00    113302

# %%
import sklearn.metrics as metrics
accuracy=metrics.accuracy_score(y_test_res, y_pred_xgb)
f1_score=metrics.f1_score(y_test_res, y_pred_xgb)
precision=metrics.precision_score(y_test_res, y_pred_xgb)
recall=metrics.recall_score(y_test_res, y_pred_xgb)
print(f'model accuracy ={100*accuracy:.2} %')
print(f'model f1_score ={100*f1_score:.2} %')
print(f'model precision ={100*precision:.2} %')
print(f'model recall ={100*recall:.2} %')
# this modelling technique is useful that accuracy is 100% and also important factor is precision which has 100% and shows how many actual truly positive.
# Out:
# model accuracy =1e+02 %
# model f1_score =1e+02 %
# model precision =1e+02 %
# model recall =1e+02 %

# %%
confmatrix=confusion_matrix(y_test_res, y_pred_xgb)
print(confmatrix)
ax=sns.heatmap(confmatrix, annot=True, cmap='Blues')
ax.set_title('seaborn confusion matrix for xgb') 
ax.set_xlabel('pridected values')
ax.set_ylabel('Actual label')
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
plt.show()
# Out:
# [[56461     0]
#  [    0 56841]]

# %% [markdown]
# ## Modling data using oversampling data using Ensemble

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
model1=DecisionTreeClassifier()
model2=LogisticRegression(max_iter=150)
model3=KNeighborsClassifier(n_neighbors=10)
final_model=VotingClassifier(estimators=[('DT',model1),('LR',model2),('KNN',model3)])
final_model.fit(x_train_res, y_train_res)
# to test ensemble model
y_pred_ensemble=final_model.predict(x_test_res)
# to evaluate  modeling
from sklearn.metrics import confusion_matrix, classification_report
class_report=classification_report(y_test_res, y_pred_ensemble)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56461
#            1       1.00      1.00      1.00     56841
#
#     accuracy                           1.00    113302
#    macro avg       1.00      1.00      1.00    113302
# weighted avg       1.00      1.00      1.00    113302

# %%
from sklearn.metrics import confusion_matrix
confmatrix=confusion_matrix(y_test_res, y_pred_ensemble)
print(confmatrix)
ax=sns.heatmap(confmatrix, annot=True, cmap='Blues')
ax.set_title('seaborn confusion matrix of ensemble') 
ax.set_xlabel('pridected values')
ax.set_ylabel('Actual label')
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
plt.show()
# Out:
# [[56461     0]
#  [    0 56841]]

# %%
import sklearn.metrics as metrics
accuracy=metrics.accuracy_score(y_test_res, y_pred_ensemble)
f1_score=metrics.f1_score(y_test_res, y_pred_ensemble)
precision=metrics.precision_score(y_test_res, y_pred_ensemble)
recall=metrics.recall_score(y_test_res, y_pred_ensemble)
print(f'model accuracy ={100*accuracy:.3} %')
print(f'model f1_score ={100*f1_score:.3} %')
print(f'model precision ={100*precision:.3} %')
print(f'model recall ={100*recall:.3} %')
# Out:
# model accuracy =1e+02 %
# model f1_score =1e+02 %
# model precision =1e+02 %
# model recall =1e+02 %

# %%
# this modelling technique is useful that accuracy is 100% and also important factor is precision which has 100% and shows how many actual truly positive.

# %% [markdown]
# ## Modeling Data using undersampling data and XGBoost

# %%
# using undersampling data
from xgboost import XGBClassifier
XGB_model=XGBClassifier()
XGB_model.fit(x_train_uos,y_train_uos)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
y_pred_uosxgb=XGB_model.predict(x_test_uos)
from sklearn.metrics import confusion_matrix, classification_report
class_report=classification_report(y_test_uos, y_pred_uosxgb)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        95
#            1       1.00      1.00      1.00        95
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190

# %%
import sklearn.metrics as metrics
accuracy=metrics.accuracy_score(y_test_uos, y_pred_uosxgb)
f1_score=metrics.f1_score(y_test_uos, y_pred_uosxgb)
precision=metrics.precision_score(y_test_uos, y_pred_uosxgb)
recall=metrics.recall_score(y_test_uos, y_pred_uosxgb)
print(f'model accuracy ={100*accuracy:.3} %')
print(f'model f1_score ={100*f1_score:.3} %')
print(f'model precision ={100*precision:.3} %')
print(f'model recall ={100*recall:.3} %')
# Out:
# model accuracy =1e+02 %
# model f1_score =1e+02 %
# model precision =1e+02 %
# model recall =1e+02 %

# %%
confmatrix=confusion_matrix(y_test_uos, y_pred_uosxgb)
print(confmatrix)
ax=sns.heatmap(confmatrix, annot=True, cmap='Blues')
ax.set_title('seaborn confusion matrix of xgb') 
ax.set_xlabel('pridected values')
ax.set_ylabel('Actual label')
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
plt.show()
# Out:
# [[95  0]
#  [ 0 95]]

# %% [markdown]
# ## Modeling Data using undersampling data and Ensemble

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
model1=DecisionTreeClassifier()
model2=LogisticRegression()
model3=KNeighborsClassifier(n_neighbors=10)
final_model=VotingClassifier(estimators=[('DT',model1),('LR',model2),('KNN',model3)])
final_model.fit(x_train_uos, y_train_uos)
y_pred_uosensemble=final_model.predict(x_test_uos)
from sklearn.metrics import confusion_matrix, classification_report
class_report=classification_report(y_test_uos, y_pred_uosensemble)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        95
#            1       1.00      1.00      1.00        95
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190

# %%
confmatrix=confusion_matrix(y_test_uos, y_pred_uosensemble)
print(confmatrix)
ax=sns.heatmap(confmatrix, annot=True, cmap='Blues')
ax.set_title('seaborn confusion matrix of ensemble') 
ax.set_xlabel('pridected values')
ax.set_ylabel('Actual label')
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
plt.show()
# Out:
# [[95  0]
#  [ 0 95]]

# %%
import sklearn.metrics as metrics
accuracy=metrics.accuracy_score(y_test_uos, y_pred_uosensemble)
f1_score=metrics.f1_score(y_test_uos,y_pred_uosensemble)
precision=metrics.precision_score(y_test_uos, y_pred_uosensemble)
recall=metrics.recall_score(y_test_uos, y_pred_uosensemble)
print(f'model accuracy ={100*accuracy:.3} %')
print(f'model f1_score ={100*f1_score:.3} %')
print(f'model precision ={100*precision:.3} %')
print(f'model recall ={100*recall:.3} %')
# Out:
# model accuracy =1e+02 %
# model f1_score =1e+02 %
# model precision =1e+02 %
# model recall =1e+02 %

# %% [markdown]
# ### from above cells using modeling methods which depend on more than one technique as XGB and ensemble obtain 100% accuracy but using oversampling technique of imbalanced data which has cost FP >cost FN and this is suitable for detecting fraud case.

# %%
from collections import Counter
from numpy import where
counter = Counter(y)
# summarize class distribution
for label, _ in counter.items():
	row_ix = where(y_train_res == label)[0]
	plt.scatter(x_train_res[row_ix, 0], x_train_res[row_ix, 1], label=str(label))
plt.legend()
plt.title('Scatter graph of training oversampling data')
plt.show()

# %%
# summarize class distribution
counter = Counter(y_pred_xgb)
for label, _ in counter.items():
	row_ix = where(y_pred_xgb == label)[0]
	plt.scatter(x_test_res[row_ix, 0], x_test_res[row_ix, 1], label=str(label))
plt.legend()
plt.title('Scatter graph of test oversampling data after Modling XGB')
plt.show()

# %%
# summarize class distribution
counter = Counter(y_pred_ensemble)
for label, _ in counter.items():
	row_ix = where(y_pred_ensemble == label)[0]
	plt.scatter(x_test_res[row_ix, 0], x_test_res[row_ix, 1], label=str(label))
plt.legend()
plt.title('Scatter graph of test oversampling data after Modling Ensemble')
plt.show()
